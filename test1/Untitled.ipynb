# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpldatacursor import datacursor
from ipysheet import sheet, cell, row, column, cell_range,from_dataframe,to_dataframe
import ipywidgets as widgets

# %%
df = pd.read_csv("data_1.dat",engine='python',skiprows=34,header=None,sep='\s+')
df.columns = ['dac1 (Vbias)','y_parameter (none)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','processed dIdV']

# %%
df['Keithley 1'].mul(100)
# Out:
# 0   -0.626065
# 1    0.378312
# 2    1.330959
# 3    2.303551
# 4    3.279120
# Name: Keithley 1, dtype: float64

# %%
sheet1 = sheet(row=3,columns=4)
cell1 = cell(0,0,'dac1 (Vbias)')

# %%
sheet1
# Out:
# U2hlZXQoY2VsbHM9KENlbGwoY29sdW1uX2VuZD0wLCBjb2x1bW5fc3RhcnQ9MCwgcm93X2VuZD0wLCByb3dfc3RhcnQ9MCwgdHlwZT11J3RleHQnLCB2YWx1ZT0nZGFjMSAoVmJpYXMpJyksKSzigKY=

# %%
sheet2 = from_dataframe(df)
sheet2
# Out:
# U2hlZXQoY2VsbHM9KENlbGwoY2hvaWNlPVtdLCBjb2x1bW5fZW5kPTAsIGNvbHVtbl9zdGFydD0wLCByb3dfZW5kPTQsIHJvd19zdGFydD0wLCBzcXVlZXplX3Jvdz1GYWxzZSwgdHlwZT11J27igKY=

# %%
fig1 = plt.figure()

ax1 = fig1.add_axes([0.1, 0.5, 0.8, 0.4])
ax2 = fig1.add_axes([0.1, 0.1, 0.8, 0.4])

#ax1.plot(df['dac1 (Vbias)'],df['Keithley 1'],df['dac1 (Vbias)'],df['Keithley 2'])
ax1.plot(df['dac1 (Vbias)'],df['Keithley 1'])
ax2.plot(df['dac1 (Vbias)'],df['Keithley 2'])
#df.plot(0,'Keithley 1',style='.-')
#plt.ylabel('Current')
#plt.xlabel('Voltage')
#plt.title('Test')

datacursor()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig2 = plt.figure()
for i in range(1, 5):
    plt.subplot(2, 2, i)
    
ax3 = fig2.add_subplot(2,2,1)
ax3.plot(df['dac1 (Vbias)'],df['Keithley 1'])

ax4 = fig2.add_subplot(2,2,2)
ax4.plot(df['dac1 (Vbias)'],df['Keithley 2'])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\ProgramData\Miniconda2\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
